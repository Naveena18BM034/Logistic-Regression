# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/weatherAUS.csv')

# %%
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
pd.set_option('display.max_columns',None)

# %%
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            NaN           W           44.0          W        WNW
# 1            NaN         WNW           44.0        NNW        WSW
# 2            NaN         WSW           46.0          W        WSW
# 3            NaN          NE           24.0         SE          E
# 4            NaN           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       NaN           E           31.0         SE        ENE
# 145456       NaN         NNW           22.0         SE          N
# 145457       NaN           N           37.0         SE        WNW
# 145458       NaN          SE           28.0        SSE          N
# 145459       NaN         NaN            NaN        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 0            1007.1       8.0       NaN     16.9     21.8        No
# 1            1007.8       NaN       NaN     17.2     24.3        No
# 2            1008.7       NaN       2.0     21.0     23.2        No
# 3            1012.8       NaN       NaN     18.1     26.5        No
# 4            1006.0       7.0       8.0     17.8     29.7        No
# ...             ...       ...       ...      ...      ...       ...
# 145455       1020.3       NaN       NaN     10.1     22.4        No
# 145456       1019.1       NaN       NaN     10.9     24.5        No
# 145457       1016.8       NaN       NaN     12.5     26.1        No
# 145458       1016.5       3.0       2.0     15.1     26.0        No
# 145459       1017.9       8.0       8.0     15.0     20.9        No
#
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459          NaN
#
# [145460 rows x 23 columns]

# %%
data = data.drop(['Evaporation','Sunshine'],axis=1)

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8        No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3        No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2        No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5        No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7        No
#
#   RainTomorrow
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No

# %%
data = data.ffill()

# %%
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  \
# 0       2008-12-01   Albury     13.4     22.9       0.6           W
# 1       2008-12-02   Albury      7.4     25.1       0.0         WNW
# 2       2008-12-03   Albury     12.9     25.7       0.0         WSW
# 3       2008-12-04   Albury      9.2     28.0       0.0          NE
# 4       2008-12-05   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0           E
# 145456  2017-06-22    Uluru      3.6     25.3       0.0         NNW
# 145457  2017-06-23    Uluru      5.4     26.9       0.0           N
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          SE
# 145459  2017-06-25    Uluru     14.9     27.0       0.0          SE
#
#         WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0                44.0          W        WNW          20.0          24.0
# 1                44.0        NNW        WSW           4.0          22.0
# 2                46.0          W        WSW          19.0          26.0
# 3                24.0         SE          E          11.0           9.0
# 4                41.0        ENE         NW           7.0          20.0
# ...               ...        ...        ...           ...           ...
# 145455           31.0         SE        ENE          13.0          11.0
# 145456           22.0         SE          N          13.0           9.0
# 145457           37.0         SE        WNW           9.0           9.0
# 145458           28.0        SSE          N          13.0           7.0
# 145459           28.0        ESE        ESE          17.0          17.0
#
#         Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 0              71.0         22.0       1007.7       1007.1       8.0
# 1              44.0         25.0       1010.6       1007.8       8.0
# 2              38.0         30.0       1007.6       1008.7       8.0
# 3              45.0         16.0       1017.6       1012.8       8.0
# 4              82.0         33.0       1010.8       1006.0       7.0
# ...             ...          ...          ...          ...       ...
# 145455         51.0         24.0       1024.6       1020.3       8.0
# 145456         56.0         21.0       1023.5       1019.1       8.0
# 145457         53.0         24.0       1021.0       1016.8       8.0
# 145458         51.0         24.0       1019.4       1016.5       3.0
# 145459         62.0         36.0       1020.2       1017.9       8.0
#
#         Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0            NaN     16.9     21.8        No           No
# 1            NaN     17.2     24.3        No           No
# 2            2.0     21.0     23.2        No           No
# 3            2.0     18.1     26.5        No           No
# 4            8.0     17.8     29.7        No           No
# ...          ...      ...      ...       ...          ...
# 145455       7.0     10.1     22.4        No           No
# 145456       7.0     10.9     24.5        No           No
# 145457       7.0     12.5     26.1        No           No
# 145458       2.0     15.1     26.0        No           No
# 145459       8.0     15.0     20.9        No           No
#
# [145460 rows x 21 columns]

# %%
data.isnull().sum().sum()
# Out:
# 2

# %%
data = data.dropna()

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (145458, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145458 entries, 2 to 145459
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145458 non-null  object
#  1   Location       145458 non-null  object
#  2   MinTemp        145458 non-null  float64
#  3   MaxTemp        145458 non-null  float64
#  4   Rainfall       145458 non-null  float64
#  5   WindGustDir    145458 non-null  object
#  6   WindGustSpeed  145458 non-null  float64
#  7   WindDir9am     145458 non-null  object
#  8   WindDir3pm     145458 non-null  object
#  9   WindSpeed9am   145458 non-null  float64
#  10  WindSpeed3pm   145458 non-null  float64
#  11  Humidity9am    145458 non-null  float64
#  12  Humidity3pm    145458 non-null  float64
#  13  Pressure9am    145458 non-null  float64
#  14  Pressure3pm    145458 non-null  float64
#  15  Cloud9am       145458 non-null  float64
#  16  Cloud3pm       145458 non-null  float64
#  17  Temp9am        145458 non-null  float64
#  18  Temp3pm        145458 non-null  float64
#  19  RainToday      145458 non-null  object
#  20  RainTomorrow   145458 non-null  object
# dtypes: float64(14), object(7)
# memory usage: 24.4+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145458 entries, 2 to 145459
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145458 non-null  object
#  1   Location       145458 non-null  object
#  2   MinTemp        145458 non-null  float64
#  3   MaxTemp        145458 non-null  float64
#  4   Rainfall       145458 non-null  float64
#  5   WindGustDir    145458 non-null  object
#  6   WindGustSpeed  145458 non-null  float64
#  7   WindDir9am     145458 non-null  object
#  8   WindDir3pm     145458 non-null  object
#  9   WindSpeed9am   145458 non-null  float64
#  10  WindSpeed3pm   145458 non-null  float64
#  11  Humidity9am    145458 non-null  float64
#  12  Humidity3pm    145458 non-null  float64
#  13  Pressure9am    145458 non-null  float64
#  14  Pressure3pm    145458 non-null  float64
#  15  Cloud9am       145458 non-null  float64
#  16  Cloud3pm       145458 non-null  float64
#  17  Temp9am        145458 non-null  float64
#  18  Temp3pm        145458 non-null  float64
#  19  RainToday      145458 non-null  object
#  20  RainTomorrow   145458 non-null  object
# dtypes: float64(14), object(7)
# memory usage: 24.4+ MB

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
# 5  2008-12-06   Albury     14.6     29.7       0.2         WNW           56.0
# 6  2008-12-07   Albury     14.3     25.0       0.0           W           50.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
# 5          W          W          19.0          24.0         55.0         23.0
# 6         SW          W          20.0          24.0         49.0         19.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 2       1007.6       1008.7       8.0       2.0     21.0     23.2        No
# 3       1017.6       1012.8       8.0       2.0     18.1     26.5        No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7        No
# 5       1009.2       1005.4       7.0       8.0     20.6     28.9        No
# 6       1009.6       1008.2       1.0       8.0     18.1     24.6        No
#
#   RainTomorrow
# 2           No
# 3           No
# 4           No
# 5           No
# 6           No

# %%
data['RainTomorrow'].value_counts()
# Out:
# RainTomorrow
# No     112699
# Yes     32759
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall  WindGustSpeed  \
# count  145458.000000  145458.000000  145458.000000  145458.000000
# mean       12.212196      23.219733       2.380978      39.456029
# std         6.395082       7.111678       8.488960      13.626571
# min        -8.500000      -4.800000       0.000000       6.000000
# 25%         7.600000      17.900000       0.000000      30.000000
# 50%        12.000000      22.700000       0.000000      37.000000
# 75%        16.900000      28.200000       0.800000      46.000000
# max        33.900000      48.100000     371.000000     135.000000
#
#         WindSpeed9am   WindSpeed3pm    Humidity9am    Humidity3pm  \
# count  145458.000000  145458.000000  145458.000000  145458.000000
# mean       14.049121      18.852081      68.903869      51.466595
# std         8.922419       9.064812      19.192725      20.881926
# min         0.000000       0.000000       0.000000       0.000000
# 25%         7.000000      13.000000      57.000000      36.000000
# 50%        13.000000      19.000000      70.000000      52.000000
# 75%        19.000000      24.000000      83.000000      66.000000
# max       130.000000      87.000000     100.000000     100.000000
#
#          Pressure9am    Pressure3pm       Cloud9am       Cloud3pm  \
# count  145458.000000  145458.000000  145458.000000  145458.000000
# mean     1017.885311    1015.530626       4.775537       4.633571
# std         6.965682       6.868580       2.854756       2.780259
# min       980.500000     977.100000       0.000000       0.000000
# 25%      1013.500000    1011.000000       2.000000       2.000000
# 50%      1018.000000    1015.600000       6.000000       5.000000
# 75%      1022.300000    1019.900000       7.000000       7.000000
# max      1041.000000    1039.600000       9.000000       9.000000
#
#              Temp9am        Temp3pm
# count  145458.000000  145458.000000
# mean       16.972661      21.685346
# std         6.502134       6.953521
# min        -7.200000      -5.400000
# 25%        12.300000      16.600000
# 50%        16.700000      21.200000
# 75%        21.500000      26.400000
# max        40.200000      46.700000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in data.columns:
  if data[i].dtype == 'object':
    data[i] = le.fit_transform(data[i])
# Out:
# <ipython-input-19-cf589dcbfc63>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = le.fit_transform(data[i])
# <ipython-input-19-cf589dcbfc63>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = le.fit_transform(data[i])
# <ipython-input-19-cf589dcbfc63>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = le.fit_transform(data[i])
# <ipython-input-19-cf589dcbfc63>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = le.fit_transform(data[i])
# <ipython-input-19-cf589dcbfc63>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = le.fit_transform(data[i])
# <ipython-input-19-cf589dcbfc63>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = le.fit_transform(data[i])
# <ipython-input-19-cf589dcbfc63>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = le.fit_transform(data[i])

# %%
data
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  WindGustDir  \
# 2        398         2     12.9     25.7       0.0           15
# 3        399         2      9.2     28.0       0.0            4
# 4        400         2     17.5     32.3       1.0           13
# 5        401         2     14.6     29.7       0.2           14
# 6        402         2     14.3     25.0       0.0           13
# ...      ...       ...      ...      ...       ...          ...
# 145455  3431        41      2.8     23.4       0.0            0
# 145456  3432        41      3.6     25.3       0.0            6
# 145457  3433        41      5.4     26.9       0.0            3
# 145458  3434        41      7.8     27.0       0.0            9
# 145459  3435        41     14.9     27.0       0.0            9
#
#         WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 2                46.0          13          15          19.0          26.0
# 3                24.0           9           0          11.0           9.0
# 4                41.0           1           7           7.0          20.0
# 5                56.0          13          13          19.0          24.0
# 6                50.0          12          13          20.0          24.0
# ...               ...         ...         ...           ...           ...
# 145455           31.0           9           1          13.0          11.0
# 145456           22.0           9           3          13.0           9.0
# 145457           37.0           9          14           9.0           9.0
# 145458           28.0          10           3          13.0           7.0
# 145459           28.0           2           2          17.0          17.0
#
#         Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 2              38.0         30.0       1007.6       1008.7       8.0
# 3              45.0         16.0       1017.6       1012.8       8.0
# 4              82.0         33.0       1010.8       1006.0       7.0
# 5              55.0         23.0       1009.2       1005.4       7.0
# 6              49.0         19.0       1009.6       1008.2       1.0
# ...             ...          ...          ...          ...       ...
# 145455         51.0         24.0       1024.6       1020.3       8.0
# 145456         56.0         21.0       1023.5       1019.1       8.0
# 145457         53.0         24.0       1021.0       1016.8       8.0
# 145458         51.0         24.0       1019.4       1016.5       3.0
# 145459         62.0         36.0       1020.2       1017.9       8.0
#
#         Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# 2            2.0     21.0     23.2          0             0
# 3            2.0     18.1     26.5          0             0
# 4            8.0     17.8     29.7          0             0
# 5            8.0     20.6     28.9          0             0
# 6            8.0     18.1     24.6          0             0
# ...          ...      ...      ...        ...           ...
# 145455       7.0     10.1     22.4          0             0
# 145456       7.0     10.9     24.5          0             0
# 145457       7.0     12.5     26.1          0             0
# 145458       2.0     15.1     26.0          0             0
# 145459       8.0     15.0     20.9          0             0
#
# [145458 rows x 21 columns]

# %%
data['RainTomorrow'].value_counts()
# Out:
# RainTomorrow
# 0    112699
# 1     32759
# Name: count, dtype: int64

# %%
x = data.drop('RainTomorrow',axis=1)
y = data['RainTomorrow']

# %%
x.shape
# Out:
# (145458, 20)

# %%
data.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  \
# 2   398         2     12.9     25.7       0.0           15           46.0
# 3   399         2      9.2     28.0       0.0            4           24.0
# 4   400         2     17.5     32.3       1.0           13           41.0
# 5   401         2     14.6     29.7       0.2           14           56.0
# 6   402         2     14.3     25.0       0.0           13           50.0
#
#    WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 2          13          15          19.0          26.0         38.0
# 3           9           0          11.0           9.0         45.0
# 4           1           7           7.0          20.0         82.0
# 5          13          13          19.0          24.0         55.0
# 6          12          13          20.0          24.0         49.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 2         30.0       1007.6       1008.7       8.0       2.0     21.0
# 3         16.0       1017.6       1012.8       8.0       2.0     18.1
# 4         33.0       1010.8       1006.0       7.0       8.0     17.8
# 5         23.0       1009.2       1005.4       7.0       8.0     20.6
# 6         19.0       1009.6       1008.2       1.0       8.0     18.1
#
#    Temp3pm  RainToday  RainTomorrow
# 2     23.2          0             0
# 3     26.5          0             0
# 4     29.7          0             0
# 5     28.9          0             0
# 6     24.6          0             0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145458 entries, 2 to 145459
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145458 non-null  int64
#  1   Location       145458 non-null  int64
#  2   MinTemp        145458 non-null  float64
#  3   MaxTemp        145458 non-null  float64
#  4   Rainfall       145458 non-null  float64
#  5   WindGustDir    145458 non-null  int64
#  6   WindGustSpeed  145458 non-null  float64
#  7   WindDir9am     145458 non-null  int64
#  8   WindDir3pm     145458 non-null  int64
#  9   WindSpeed9am   145458 non-null  float64
#  10  WindSpeed3pm   145458 non-null  float64
#  11  Humidity9am    145458 non-null  float64
#  12  Humidity3pm    145458 non-null  float64
#  13  Pressure9am    145458 non-null  float64
#  14  Pressure3pm    145458 non-null  float64
#  15  Cloud9am       145458 non-null  float64
#  16  Cloud3pm       145458 non-null  float64
#  17  Temp9am        145458 non-null  float64
#  18  Temp3pm        145458 non-null  float64
#  19  RainToday      145458 non-null  int64
#  20  RainTomorrow   145458 non-null  int64
# dtypes: float64(14), int64(7)
# memory usage: 24.4 MB

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
smote = SMOTE(random_state=42)
x_resampled, y_resampled = smote.fit_resample(x_train, y_train)

# %%
#LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=1)
x = lda.fit_transform(x_resampled, y_resampled)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y_resampled, test_size= 0.3, random_state=29)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr_pred = lr.predict(x_test)

# %%
from sklearn.metrics import *

# %%
accuracy_score(lr_pred, y_test)
# Out:
# 0.7700061030866823

# %%
cr = classification_report(lr_pred, y_test)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77     27430
#            1       0.76      0.77      0.77     26641
#
#     accuracy                           0.77     54071
#    macro avg       0.77      0.77      0.77     54071
# weighted avg       0.77      0.77      0.77     54071

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# Training the model
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = model.predict(x_test)
predictions
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predictions)
# Out:
# 0.6900556675482237

# %%
cr = classification_report(y_test,predictions)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69     27090
#            1       0.69      0.69      0.69     26981
#
#     accuracy                           0.69     54071
#    macro avg       0.69      0.69      0.69     54071
# weighted avg       0.69      0.69      0.69     54071
